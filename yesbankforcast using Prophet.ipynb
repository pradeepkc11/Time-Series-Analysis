# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("yes bank.csv")

# %%
df.head()
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0      NaN    NaN        NaN         NaN         NaN         NaN        NaN
# 1  YESBANK     EQ  13-Mar-19      235.85       236.0      247.60     232.70
# 2  YESBANK     EQ  14-Mar-19      244.30       248.0      254.00     246.15
# 3  YESBANK     EQ  15-Mar-19      249.85       251.7      252.80     243.50
# 4  YESBANK     EQ  18-Mar-19      245.05       247.0      248.55     241.80
#
#    Last Price  Close Price    VWAP Total Traded            Turnover    No. of  \
# 0         NaN          NaN     NaN     Quantity                 NaN    Trades
# 1      244.25       244.30  242.07  5,88,83,298  14,25,41,19,799.40  3,07,346
# 2      250.15       249.85  250.85  5,96,84,202  14,97,17,75,478.60  3,30,601
# 3      245.05       245.05  247.39  3,87,15,468   9,57,79,21,922.20  2,06,568
# 4      246.80       245.95  245.24  2,48,25,632   6,08,82,15,385.80  1,37,716
#
#    Deliverable % Dly Qt to
# ...

# %%
df.head()
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0      NaN    NaN        NaN         NaN         NaN         NaN        NaN
# 1  YESBANK     EQ  13-Mar-19      235.85       236.0      247.60     232.70
# 2  YESBANK     EQ  14-Mar-19      244.30       248.0      254.00     246.15
# 3  YESBANK     EQ  15-Mar-19      249.85       251.7      252.80     243.50
# 4  YESBANK     EQ  18-Mar-19      245.05       247.0      248.55     241.80
#
#    Last Price  Close Price    VWAP Total Traded            Turnover    No. of  \
# 0         NaN          NaN     NaN     Quantity                 NaN    Trades
# 1      244.25       244.30  242.07  5,88,83,298  14,25,41,19,799.40  3,07,346
# 2      250.15       249.85  250.85  5,96,84,202  14,97,17,75,478.60  3,30,601
# 3      245.05       245.05  247.39  3,87,15,468   9,57,79,21,922.20  2,06,568
# 4      246.80       245.95  245.24  2,48,25,632   6,08,82,15,385.80  1,37,716
#
#    Deliverable % Dly Qt to
# ...

# %%
df.isnull().sum()
# Out:
# Symbol          1
# Series          1
# Date            1
# Prev Close      1
# Open Price      1
# High Price      1
# Low Price       1
# Last Price      1
# Close Price     1
# VWAP            1
# Total Traded    0
# Turnover        1
# No. of          0
# Deliverable     0
# % Dly Qt to     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 1  YESBANK     EQ  13-Mar-19      235.85      236.00      247.60     232.70
# 2  YESBANK     EQ  14-Mar-19      244.30      248.00      254.00     246.15
# 3  YESBANK     EQ  15-Mar-19      249.85      251.70      252.80     243.50
# 4  YESBANK     EQ  18-Mar-19      245.05      247.00      248.55     241.80
# 5  YESBANK     EQ  19-Mar-19      245.95      246.65      250.50     245.00
#
#    Last Price  Close Price    VWAP Total Traded            Turnover    No. of  \
# 1      244.25       244.30  242.07  5,88,83,298  14,25,41,19,799.40  3,07,346
# 2      250.15       249.85  250.85  5,96,84,202  14,97,17,75,478.60  3,30,601
# 3      245.05       245.05  247.39  3,87,15,468   9,57,79,21,922.20  2,06,568
# 4      246.80       245.95  245.24  2,48,25,632   6,08,82,15,385.80  1,37,716
# 5      249.35       248.80  248.34  2,14,48,040   5,32,63,20,590.75  1,44,647
#
#    Deliverable % Dly Qt to
# ...

# %%
df.drop("Symbol",axis=1,inplace=True)

# %%
df.head()
# Out:
#   Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 1     EQ  13-Mar-19      235.85      236.00      247.60     232.70
# 2     EQ  14-Mar-19      244.30      248.00      254.00     246.15
# 3     EQ  15-Mar-19      249.85      251.70      252.80     243.50
# 4     EQ  18-Mar-19      245.05      247.00      248.55     241.80
# 5     EQ  19-Mar-19      245.95      246.65      250.50     245.00
#
#    Last Price  Close Price    VWAP Total Traded            Turnover    No. of  \
# 1      244.25       244.30  242.07  5,88,83,298  14,25,41,19,799.40  3,07,346
# 2      250.15       249.85  250.85  5,96,84,202  14,97,17,75,478.60  3,30,601
# 3      245.05       245.05  247.39  3,87,15,468   9,57,79,21,922.20  2,06,568
# 4      246.80       245.95  245.24  2,48,25,632   6,08,82,15,385.80  1,37,716
# 5      249.35       248.80  248.34  2,14,48,040   5,32,63,20,590.75  1,44,647
#
#    Deliverable % Dly Qt to
# 1  1,10,98,533       18.85
# 2  1,05,93,357       17.75
# ...

# %%
df.drop("Series",axis=1,inplace=True)

# %%
df.head()
# Out:
#         Date  Prev Close  Open Price  High Price  Low Price  Last Price  \
# 1  13-Mar-19      235.85      236.00      247.60     232.70      244.25
# 2  14-Mar-19      244.30      248.00      254.00     246.15      250.15
# 3  15-Mar-19      249.85      251.70      252.80     243.50      245.05
# 4  18-Mar-19      245.05      247.00      248.55     241.80      246.80
# 5  19-Mar-19      245.95      246.65      250.50     245.00      249.35
#
#    Close Price    VWAP Total Traded            Turnover    No. of  \
# 1       244.30  242.07  5,88,83,298  14,25,41,19,799.40  3,07,346
# 2       249.85  250.85  5,96,84,202  14,97,17,75,478.60  3,30,601
# 3       245.05  247.39  3,87,15,468   9,57,79,21,922.20  2,06,568
# 4       245.95  245.24  2,48,25,632   6,08,82,15,385.80  1,37,716
# 5       248.80  248.34  2,14,48,040   5,32,63,20,590.75  1,44,647
#
#    Deliverable % Dly Qt to
# 1  1,10,98,533       18.85
# 2  1,05,93,357       17.75
# 3  1,07,90,762       27.87
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 245 entries, 1 to 245
# Data columns (total 13 columns):
# Date            245 non-null object
# Prev Close      245 non-null float64
# Open Price      245 non-null float64
# High Price      245 non-null float64
# Low Price       245 non-null float64
# Last Price      245 non-null float64
# Close Price     245 non-null float64
# VWAP            245 non-null float64
# Total Traded    245 non-null object
# Turnover        245 non-null object
# No. of          245 non-null object
# Deliverable     245 non-null object
# % Dly Qt to     245 non-null object
# dtypes: float64(7), object(6)
# memory usage: 26.8+ KB

# %%
df["Date"]=pd.to_datetime(df["Date"],format="%d-%b-%y")

# %%
df.head()
# Out:
#         Date  Prev Close  Open Price  High Price  Low Price  Last Price  \
# 1 2019-03-13      235.85      236.00      247.60     232.70      244.25
# 2 2019-03-14      244.30      248.00      254.00     246.15      250.15
# 3 2019-03-15      249.85      251.70      252.80     243.50      245.05
# 4 2019-03-18      245.05      247.00      248.55     241.80      246.80
# 5 2019-03-19      245.95      246.65      250.50     245.00      249.35
#
#    Close Price    VWAP Total Traded            Turnover    No. of  \
# 1       244.30  242.07  5,88,83,298  14,25,41,19,799.40  3,07,346
# 2       249.85  250.85  5,96,84,202  14,97,17,75,478.60  3,30,601
# 3       245.05  247.39  3,87,15,468   9,57,79,21,922.20  2,06,568
# 4       245.95  245.24  2,48,25,632   6,08,82,15,385.80  1,37,716
# 5       248.80  248.34  2,14,48,040   5,32,63,20,590.75  1,44,647
#
#    Deliverable % Dly Qt to
# 1  1,10,98,533       18.85
# 2  1,05,93,357       17.75
# 3  1,07,90,762       27.87
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price',
#        'Last Price', 'Close Price', 'VWAP', 'Total Traded', 'Turnover',
#        'No. of', 'Deliverable', '% Dly Qt to'],
#       dtype='object')

# %%
col=['Date', 'prev_close', 'open', 'high', 'low',
       'last', 'close', 'vmap', 'total', 'turnover',
       'No', 'deliverable', 'dly']

# %%
df.columns=col

# %%
df.head()
# Out:
#         Date  prev_close    open    high     low    last   close    vmap  \
# 1 2019-03-13      235.85  236.00  247.60  232.70  244.25  244.30  242.07
# 2 2019-03-14      244.30  248.00  254.00  246.15  250.15  249.85  250.85
# 3 2019-03-15      249.85  251.70  252.80  243.50  245.05  245.05  247.39
# 4 2019-03-18      245.05  247.00  248.55  241.80  246.80  245.95  245.24
# 5 2019-03-19      245.95  246.65  250.50  245.00  249.35  248.80  248.34
#
#          total            turnover        No  deliverable    dly
# 1  5,88,83,298  14,25,41,19,799.40  3,07,346  1,10,98,533  18.85
# 2  5,96,84,202  14,97,17,75,478.60  3,30,601  1,05,93,357  17.75
# 3  3,87,15,468   9,57,79,21,922.20  2,06,568  1,07,90,762  27.87
# 4  2,48,25,632   6,08,82,15,385.80  1,37,716    47,52,203  19.14
# 5  2,14,48,040   5,32,63,20,590.75  1,44,647    46,21,743  21.55

# %%
f, (ax1) = plt.subplots(1, figsize=(14,5))
ax1.plot(df["Date"], df["close"])
ax1.set_xlabel("Date", fontsize=12)
ax1.set_ylabel("Stock Price")
ax1.set_title("Yes Bank Close Price History");

# Second Subplot
ax1.plot(df["Date"], df["high"], color="green")
ax1.set_xlabel("Date", fontsize=12)
ax1.set_ylabel("Stock Price")
ax1.set_title("Yes Bank High Price History")

# Third Subplot
ax1.plot(df["Date"], df["low"], color="red")
ax1.set_xlabel("Date", fontsize=12)
ax1.set_ylabel("Stock Price")
ax1.set_title("Yes bank Low Price History")
# Out:
# C:\Users\prade\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Yes bank Low Price History')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 245 entries, 1 to 245
# Data columns (total 13 columns):
# Date           245 non-null datetime64[ns]
# prev_close     245 non-null float64
# open           245 non-null float64
# high           245 non-null float64
# low            245 non-null float64
# last           245 non-null float64
# close          245 non-null float64
# vmap           245 non-null float64
# total          245 non-null object
# turnover       245 non-null object
# No             245 non-null object
# deliverable    245 non-null object
# dly            245 non-null object
# dtypes: datetime64[ns](1), float64(7), object(5)
# memory usage: 26.8+ KB

# %%
from fbprophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
m=Prophet()

# %%
df.drop("high",axis=1,inplace=True)

# %%
df.head()
# Out:
#         Date  prev_close    open     low    last   close    vmap        total  \
# 1 2019-03-13      235.85  236.00  232.70  244.25  244.30  242.07  5,88,83,298
# 2 2019-03-14      244.30  248.00  246.15  250.15  249.85  250.85  5,96,84,202
# 3 2019-03-15      249.85  251.70  243.50  245.05  245.05  247.39  3,87,15,468
# 4 2019-03-18      245.05  247.00  241.80  246.80  245.95  245.24  2,48,25,632
# 5 2019-03-19      245.95  246.65  245.00  249.35  248.80  248.34  2,14,48,040
#
#              turnover        No  deliverable    dly
# 1  14,25,41,19,799.40  3,07,346  1,10,98,533  18.85
# 2  14,97,17,75,478.60  3,30,601  1,05,93,357  17.75
# 3   9,57,79,21,922.20  2,06,568  1,07,90,762  27.87
# 4   6,08,82,15,385.80  1,37,716    47,52,203  19.14
# 5   5,32,63,20,590.75  1,44,647    46,21,743  21.55

# %%
df.drop(["open","prev_close"],axis=1)
# Out:
#           Date     low    last   close    vmap           total  \
# 1   2019-03-13  232.70  244.25  244.30  242.07     5,88,83,298
# 2   2019-03-14  246.15  250.15  249.85  250.85     5,96,84,202
# 3   2019-03-15  243.50  245.05  245.05  247.39     3,87,15,468
# 4   2019-03-18  241.80  246.80  245.95  245.24     2,48,25,632
# 5   2019-03-19  245.00  249.35  248.80  248.34     2,14,48,040
# ..         ...     ...     ...     ...     ...             ...
# 241 2020-03-03   30.50   31.40   31.20   31.78    16,42,68,356
# 242 2020-03-04   28.70   29.30   29.30   29.77    20,28,51,281
# 243 2020-03-05   28.00   37.20   36.80   34.82    78,47,03,310
# 244 2020-03-06    5.65   16.60   16.15   14.75  1,26,49,17,719
# 245 2020-03-09   16.20   21.35   21.25   20.24    72,75,71,816
#
#                turnover         No   deliverable    dly
# 1    14,25,41,19,799.40   3,07,346   1,10,98,533  18.85
# 2    14,97,17,75,478.60   3,30,601   1,05,93,357  17.75
# ...

# %%
df.drop(["low","last","vmap"],inplace=True,axis=1)

# %%
df.head()
# Out:
#         Date  prev_close    open   close        total            turnover  \
# 1 2019-03-13      235.85  236.00  244.30  5,88,83,298  14,25,41,19,799.40
# 2 2019-03-14      244.30  248.00  249.85  5,96,84,202  14,97,17,75,478.60
# 3 2019-03-15      249.85  251.70  245.05  3,87,15,468   9,57,79,21,922.20
# 4 2019-03-18      245.05  247.00  245.95  2,48,25,632   6,08,82,15,385.80
# 5 2019-03-19      245.95  246.65  248.80  2,14,48,040   5,32,63,20,590.75
#
#          No  deliverable    dly
# 1  3,07,346  1,10,98,533  18.85
# 2  3,30,601  1,05,93,357  17.75
# 3  2,06,568  1,07,90,762  27.87
# 4  1,37,716    47,52,203  19.14
# 5  1,44,647    46,21,743  21.55

# %%
df.drop(["prev_close","open","total","turnover","No","deliverable"],axis=1,inplace=True)

# %%
df.head()
# Out:
#         Date   close    dly
# 1 2019-03-13  244.30  18.85
# 2 2019-03-14  249.85  17.75
# 3 2019-03-15  245.05  27.87
# 4 2019-03-18  245.95  19.14
# 5 2019-03-19  248.80  21.55

# %%
df.drop(["dly"],axis=1,inplace=True)

# %%
df.head()
# Out:
#         Date   close
# 1 2019-03-13  244.30
# 2 2019-03-14  249.85
# 3 2019-03-15  245.05
# 4 2019-03-18  245.95
# 5 2019-03-19  248.80

# %%
df.rename(columns={"Date":"ds","close":"y"},inplace=True)

# %%
m.fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_price=m.make_future_dataframe(periods=365)
forcast=m.predict(future_price)

# %%
forcast[["ds","yhat","yhat_lower","yhat_upper"]].tail(10)
# Out:
#             ds       yhat  yhat_lower  yhat_upper
# 510 2020-11-30 -23.167264 -120.733778   86.583499
# 511 2020-12-01 -23.804316 -126.881474   84.154124
# 512 2020-12-02 -24.445915 -128.726039   82.289783
# 513 2020-12-03 -23.706896 -127.467809   86.624678
# 514 2020-12-04 -25.627308 -132.552419   83.694166
# ..         ...        ...         ...         ...
# 605 2021-03-05 -44.709370 -205.197122  122.063634
# 606 2021-03-06 -45.338247 -210.758132  117.458441
# 607 2021-03-07 -44.707997 -205.725819  120.202986
# 608 2021-03-08 -43.717177 -204.169462  126.478981
# 609 2021-03-09 -44.354229 -213.322634  123.366022
#
# [100 rows x 4 columns]

# %%
import matplotlib.dates as mdates
import datetime as dt

starting_date=dt.datetime(2019,3,13)
starting_date1=mdates.date2num(starting_date)
trend_date=dt.datetime(2019,3,13)
trend_date1=mdates.date2num(trend_date)

pointing_arrow=dt.datetime(2019,9,10)
pointing_arrow1=mdates.date2num(pointing_arrow)

fig=m.plot(forcast)
ax1=fig.add_subplot(111)
ax1.set_title("Yes bank price forcast",fontsize=16)
ax1.set_xlabel("Date",fontsize=12)
ax1.set_ylabel("Close Price",fontsize=12)

ax1.annotate("Forecast \n Initialization",xy=(pointing_arrow1,10),xytext=(starting_date1,1700),
            arrowprops=dict(facecolor="#6cff6c",shrink=0.1),)
ax1.axhline(y=1260, color="b", linestyle="-")

plt.show()
# Out:
# C:\Users\prade\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   del sys.path[0]

# %%
fig2=m.plot_components(forcast)
plt.show()

# %%
m=Prophet(changepoint_prior_scale=0.01).fit(df)
future=m.make_future_dataframe(periods=12,freq="M",include_history=True)
fcst=m.predict(future)
fig=m.plot(fcst)
plt.title("Monthly Prediction \n 1year time frame")

plt.show()
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
fig = m.plot_components(fcst)
plt.show()
